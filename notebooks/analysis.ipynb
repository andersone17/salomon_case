# %%
import pandas as pd
import numpy as np
import os
import sys
from pathlib import Path


PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "notebooks").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent


data = pd.read_csv(f"{PROJECT_ROOT}/data/mock/product_daily.csv")

# %%
data = data.sort_values(by='average_selling_price', ascending=False)
data = data[data['franchise'] == 'Vestal Pro']

# %%
data.head()
# Out:
#            date campaign_phase   franchise  category  sessions  units_sold  \
# 744  2026-07-03  Post-campaign  Vestal Pro  Footwear       411          14
# 726  2026-06-30  Post-campaign  Vestal Pro  Footwear       305           7
# 762  2026-07-06  Post-campaign  Vestal Pro  Footwear       298          10
# 822  2026-07-16  Post-campaign  Vestal Pro  Footwear       356           8
# 702  2026-06-26  Post-campaign  Vestal Pro  Footwear       380          12
#
#      net_revenue  average_selling_price  inventory_ats  in_stock_rate  \
# 744      2401.50                 171.54            508         0.6168
# 726      1193.30                 170.47            547         0.6272
# 762      1695.38                 169.54            470         0.6154
# 822      1355.79                 169.47            336         0.6113
# 702      2025.16                 168.76            595         0.6947
#
#      core_size_availability  return_rate
# 744                  0.4246          0.0
# ...

# %%
# ASP
